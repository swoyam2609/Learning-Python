# %%
import pandas as pd

# %%
df = pd.read_csv("./train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip3 install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.1.2-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.9/345.9 kB 11.8 MB/s eta 0:00:00
# Collecting scipy<1.10,>=1.4.1 (from ydata-profiling->pandas-profiling)
#   Downloading scipy-1.9.3-cp39-cp39-macosx_12_0_arm64.whl (28.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.6/28.6 MB 4.2 MB/s eta 0:00:0000:0100:01m
# Collecting pandas!=1.4.0,<1.6,>1.1 (from ydata-profiling->pandas-profiling)
#   Downloading pandas-1.5.3-cp39-cp39-macosx_11_0_arm64.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib<3.7,>=3.2 (from ydata-profiling->pandas-profiling)
#   Downloading matplotlib-3.6.3-cp39-cp39-macosx_11_0_arm64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 4.8 MB/s eta 0:00:0000:0100:01m
# Collecting pydantic<1.11,>=1.8.1 (from ydata-profiling->pandas-profiling)
#   Downloading pydantic-1.10.8-cp39-cp39-macosx_11_0_arm64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata-profiling->pandas-profiling)
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 9.8 MB/s eta 0:00:00
# Collecting numpy<1.24,>=1.16.0 (from ydata-profiling->pandas-profiling)
#   Downloading numpy-1.23.5-cp39-cp39-macosx_11_0_arm64.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 4.3 MB/s eta 0:00:0000:0100:01
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.3-cp39-cp39-macosx_11_0_arm64.whl (649 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 649.9/649.9 kB 8.7 MB/s eta 0:00:00a 0:00:01
# Collecting requests<2.29,>=2.24.0 (from ydata-profiling->pandas-profiling)
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting tqdm<4.65,>=4.48.2 (from ydata-profiling->pandas-profiling)
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Collecting multimethod<1.10,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting statsmodels<0.14,>=0.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading statsmodels-0.13.5-cp39-cp39-macosx_11_0_arm64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 8.1 MB/s eta 0:00:0000:0100:01m
# Collecting typeguard<2.14,>=2.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 6.3 MB/s eta 0:00:00a 0:00:01
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->pandas-profiling)
#   Downloading PyWavelets-1.4.1-cp39-cp39-macosx_11_0_arm64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 7.5 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: pillow in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.5.0)
# Requirement already satisfied: attrs>=19.3.0 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (23.1.0)
# Collecting networkx>=2.4 (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.5 MB/s eta 0:00:0000:0100:01m
# Collecting tangled-up-in-unicode>=0.0.4 (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 5.0 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Collecting urllib3<1.27,>=1.21.1 (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maverick/Library/Python/3.9/lib/python/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2023.5.7)
# Collecting patsy>=0.5.2 (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (1.15.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=24f43557ce18043b92877dcd4fda3f9c1c0fa85ebc3361b0b116509374c00ff6
#   Stored in directory: /Users/maverick/Library/Caches/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: htmlmin, urllib3, typeguard, tqdm, tangled-up-in-unicode, pydantic, numpy, networkx, multimethod, scipy, requests, PyWavelets, patsy, pandas, visions, statsmodels, matplotlib, imagehash, phik, ydata-profiling, pandas-profiling
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.2
#     Uninstalling urllib3-2.0.2:
#       Successfully uninstalled urllib3-2.0.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.30.0
#     Uninstalling requests-2.30.0:
#       Successfully uninstalled requests-2.30.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed PyWavelets-1.4.1 htmlmin-0.1.12 imagehash-4.3.1 matplotlib-3.6.3 multimethod-1.9.1 networkx-3.1 numpy-1.23.5 pandas-1.5.3 pandas-profiling-3.6.6 patsy-0.5.3 phik-0.12.3 pydantic-1.10.8 requests-2.28.2 scipy-1.9.3 statsmodels-0.13.5 tangled-up-in-unicode-0.2.0 tqdm-4.64.1 typeguard-2.13.3 urllib3-1.26.16 visions-0.7.5 ydata-profiling-4.1.2

# %%
from pandas_profiling import ProfileReport
report = ProfileReport(df)
report.to_file(output_file='output.html')
# Out:
# Summarize dataset:  85%|████████▌ | 40/47 [00:01<00:00, 23.82it/s, Missing diagram bar]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/pc/9c01j4c97lj6kf65dsrjqm0w0000gn/T/ipykernel_67061/2613144296.py in ?()
# ----> 3 from pandas_profiling import ProfileReport
#       4 report = ProfileReport(df)
#       5 report.to_file(output_file='output.html')
#
# ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/profile_report.py in ?(self, output_file, silent)
#     305                 if self.config.html.assets_prefix is None:
#     306                     self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     307                 create_html_assets(self.config, output_file)
#     308
# --> 309             data = self.to_html()
#     310
#     311             if output_file.suffix != ".html":
#     312                 suffix = output_file.suffix
#
# ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/profile_report.py in ?(self)
#     416         Returns:
#     417             Profiling report html including wrapper.
#     418
#     419         """
# --> 420         return self.html
#
# ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/profile_report.py in ?(self)
#     228     @property
#     229     def html(self) -> str:
#     230         if self._html is None:
# --> 231             self._html = self._render_html()
#     232         return self._html
#
# ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/profile_report.py in ?(self)
#     336     def _render_html(self) -> str:
#     337         from pandas_profiling.report.presentation.flavours import HTMLReport
#     338
# --> 339         report = self.report
#     340
#     341         with tqdm(
#     342             total=1, desc="Render HTML", disable=not self.config.progress_bar
#
# ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/profile_report.py in ?(self)
#     222     @property
#     223     def report(self) -> Root:
#     224         if self._report is None:
# --> 225             self._report = get_report_structure(self.config, self.description_set)
#     226         return self._report
#
# ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/profile_report.py in ?(self)
#     204     @property
#     205     def description_set(self) -> Dict[str, Any]:
#     206         if self._description_set is None:
# --> 207             self._description_set = describe_df(
#     208                 self.config,
#     209                 self.df,
#     210                 self.summarizer,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/model/describe.py in ?(config, df, summarizer, typeset, sample)
#     160         pbar.update()
#     161
#     162         pbar.set_postfix_str("Completed")
#     163
# --> 164         date_end = datetime.utcnow()
#     165
#     166     analysis = {
#     167         "title": config.title,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/model/describe.py in ?(.0)
#     129 def describe(
# --> 130     config: Settings,
#     131     df: pd.DataFrame,
#     132     summarizer: BaseSummarizer,
#     133     typeset: VisionsTypeset,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/utils/progress_bar.py in ?(*args, **kwargs)
#       8     @wraps(fn)
#       9     def inner(*args, **kwargs) -> Any:
#      10         bar.set_postfix_str(message)
# ---> 11         ret = fn(*args, **kwargs)
#      12         bar.update()
#      13         return ret
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/model/missing.py in ?(config, df, settings)
#     108
#     109     if len(df) == 0:
#     110         return None
#     111
# --> 112     result = handle_missing(settings["name"], settings["function"])(config, df)
#     113     if result is None:
#     114         return None
#     115
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/model/missing.py in ?(*args, **kwargs)
#      86
#      87         try:
#      88             return fn(*args, *kwargs)
#      89         except ValueError as e:
# ---> 90             warn_missing(name, str(e))
#
# ~/Library/Python/3.9/lib/python/site-packages/multimethod/__init__.py in ?(self, *args, **kwargs)
#     313         func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314         try:
#     315             return func(*args, **kwargs)
#     316         except TypeError as ex:
# --> 317             raise DispatchError(f"Function {func.__code__}") from ex
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/model/pandas/missing_pandas.py in ?(config, df)
#      12 @missing_bar.register
#      13 def pandas_missing_bar(config: Settings, df: pd.DataFrame) -> str:
# ---> 14     return plot_missing_bar(config, df)
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py in ?(*args, **kwds)
#      76         @wraps(func)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/visualisation/missing.py in ?(config, data)
#      69
#      70     Returns:
#      71         The resulting missing values bar plot encoded as a string.
#      72     """
# ---> 73     missing_bar(
#      74         data,
#      75         figsize=(10, 5),
#      76         fontsize=get_font_size(data),
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas_profiling/visualisation/plot.py in ?(data, figsize, fontsize, labels, color, label_rotation)
#     788     values = null_counts.values
#     789     null_counts = null_counts / len(data)
#     790
#     791     if len(values) <= 50:
# --> 792         ax0 = null_counts.plot.bar(figsize=figsize, fontsize=fontsize, color=color)
#     793         ax0.set_xticklabels(
#     794             ax0.get_xticklabels(),
#     795             ha="right",
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/plotting/_core.py in ?(self, x, y, **kwargs)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/plotting/_core.py in ?(self, *args, **kwargs)
#     971             warnings.warn(
#     972                 "`sort_columns` is deprecated and will be removed in a future "
#     973                 "version.",
#     974                 FutureWarning,
# --> 975                 stacklevel=find_stack_level(),
#     976             )
#     977
#     978         if args and isinstance(data, ABCSeries):
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/plotting/_matplotlib/__init__.py in ?(data, kind, **kwargs)
#      67             with plt.rc_context():
#      68                 ax = plt.gca()
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/plotting/_matplotlib/core.py in ?(self)
#     448     def generate(self) -> None:
#     449         self._args_adjust()
# --> 450         self._compute_plot_data()
#     451         self._setup_subplots()
#     452         self._make_plot()
#     453         self._add_table()
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/plotting/_matplotlib/core.py in ?(self)
#     604             data = reconstruct_data_with_by(self.data, by=self.by, cols=self.columns)
#     605
#     606         # GH16953, _convert is needed as fallback, for ``Series``
#     607         # with ``dtype == object``
# --> 608         data = data._convert(datetime=True, timedelta=True)
#     609         include_type = [np.number, "datetime", "datetimetz", "timedelta"]
#     610
#     611         # GH23719, allow plotting boolean
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_convert'
